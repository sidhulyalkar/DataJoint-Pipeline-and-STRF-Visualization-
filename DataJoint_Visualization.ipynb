# %%
import cv2
from matplotlib import pyplot as plt
from retl_ppl2 import *

# %%
strfimages = STRFimages()
strfimages

# %% [markdown]
# <font size="4">Manually choose data_count and delay length desired for visualization</font>

# %%
# Choose neuron data count and delay id 
tmpimg = strfimages & 'data_count=21' & 'dp_id = 1'
img = tmpimg.fetch('strf_image')

# For specifc fetch session data for specific data_count
tmpsess = session & 'data_count=21'
tmpsess
# Out:
# *data_count    session_date   sample_number  subject_name
# +------------+ +------------+ +------------+ +------------+
# 21             2008-06-24     2              KO (chx10)
#  (Total: 1)

# %% [markdown]
# <font size="4">Visualize STRF image</font>

# %%
# Visualize chosen STRF image
plt.imshow(img[0], cmap='gray')
